# %% [markdown]
# ## Структуровані масиви даних

# %%
def homework(message):
    print("\n>>>>>", message, "\n")
import numpy as np

# %% [markdown]
# ## Визначення однорідного масиву

# %%
lst = [ [3.4, 8.7, 9.9], 
        [1.1, -7.8, -0.7],
        [4.1, 12.3, 4.8] ]

A = np.array(lst, dtype=np.int8)
print(f"Отриманий масив має вигляд:\n{repr(A)}")
B = np.array(lst, dtype=np.float16)
print(f"Отриманий масив має вигляд:\n{repr(B)}")

homework("Згадуючи ООП, що робить функція repr?")
print(f"Функція repr призначена для представлення об'єкта у вигляді рядка, який можна використовувати для відтворення об'єкта. \nУ випадку з масивами NumPy, repr надає рядок, який відображає масив у такий спосіб, що його можна відтворити за допомогою конструктора масиву.")
homework("У чому різниця між масивами A i B?")
print(f"В даному випадку масив A створюється з типом даних np.int8, що вказує на цілочисельний тип з 8 бітами на елемент.\nТут масив B створюється з типом даних np.float16, що вказує на тип числа з плаваючою комою з 16 бітами.")
print(f"Отже, різниця полягає в типах даних, які ви використовуєте для представлення чисел у масивах. \nТип даних визначає, які значення можуть бути збережені в масиві, і яким чином вони будуть представлені в пам'яті.")
# Out:
# Отриманий масив має вигляд:
# array([[ 3,  8,  9],
#        [ 1, -7,  0],
#        [ 4, 12,  4]], dtype=int8)
# Отриманий масив має вигляд:
# array([[ 3.4,  8.7,  9.9],
#        [ 1.1, -7.8, -0.7],
#        [ 4.1, 12.3,  4.8]], dtype=float16)
#
# >>>>> Згадуючи ООП, що робить функція repr?
#
# Функція repr призначена для представлення об'єкта у вигляді рядка, який можна використовувати для відтворення об'єкта.
# У випадку з масивами NumPy, repr надає рядок, який відображає масив у такий спосіб, що його можна відтворити за допомогою конструктора масиву.
#
# >>>>> У чому різниця між масивами A i B?
#
# В даному випадку масив A створюється з типом даних np.int8, що вказує на цілочисельний тип з 8 бітами на елемент.
# Тут масив B створюється з типом даних np.float16, що вказує на тип числа з плаваючою комою з 16 бітами.
# Отже, різниця полягає в типах даних, які ви використовуєте для представлення чисел у масивах.
# ...

# %% [markdown]
# ## Задаємо свій тип даних

# %%
dt = np.dtype([('name', np.compat.unicode, 20), ('mark', np.int8)])
arr = [
    ("Bohdan", 4), 
    ("Marta", 5),
    ("Noname", 0)
    ]
C = np.array(arr, dtype=dt)
print(f"Отриманий масив має вигляд:\n{C}")
print(f"Доступитись до певної колонки тепер можна за її іменем: {C['mark']}")

homework("Вивів всі імена присутні в даному масиві")
names = C['name']
print(f"Всі імена: {names}")
# Out:
# Отриманий масив має вигляд:
# [('Bohdan', 4) ('Marta', 5) ('Noname', 0)]
# Доступитись до певної колонки тепер можна за її іменем: [4 5 0]
#
# >>>>> Вивів всі імена присутні в даному масиві
#
# Всі імена: ['Bohdan' 'Marta' 'Noname']

# %% [markdown]
# ## Запис та зчитування з файлу, формат CSV

# %% [markdown]
# >savez та load найпростіші функції для збереження даних NPZ формат; CSV - формат, де значення відділені комою. Деколи цей формат дуже подібний до комірок Excel; savetxt - метод дозволяє збуурегти масив у файл; genfromtxt - метод вичитує дані з файлі;

# %%
import numpy as np

# Додамо поле "group" до масиву
C = np.array([('Bohdan', 4, 'A'), ('Marta', 5, 'B'), ('Noname', 0, 'C')],
             dtype=[('name', 'U10'), ('mark', int), ('group', 'U1')])

# Допишемо ваше ім'я, оцінку та групу
my_info = ('Nazar', 4, 'B')
C = np.append(C, np.array([my_info], dtype=C.dtype))

print("Вихідний масив: ", C)
np.savez("my_mass.npz", my_mass=C)
D = np.load("my_mass.npz")
print("Прочитаний з файлу: ", D["my_mass"])

filename = "temp.csv"
print(f"Записуємо у CSV файл {filename} значення:\n{C}")
np.savetxt(filename, C, fmt="%s,%d,%s", header="name,mark,group", delimiter=",")

import os
print(f"Перевіряємо чи файл {filename} створився: {os.listdir()}")

print("Читаємо файл за допомогою оператора with та методу readlines")
with open(filename) as f:
    D = f.readlines()

print(f"Прочитаний файл:\n {D} \n- як бачимо - {len(D)} елементи є стрічками {type(D[0])}.")

dt = np.dtype([('name', 'U10'), ('mark', int), ('group', 'U1')])
D = np.genfromtxt(filename, dtype=dt, delimiter=",", skip_header=1)

print(f"Зчитане значення з файла:\n {D}, як бачимо - {D.size} елементи це {type(D[0])} \n- вбудований клас бібліотеки numpy.")
print(f"Доступитись до певного елемента можна наступним чином, наприклад імя першого елементу: {D[0]['name']}")

# Прочитаємо ваше ім'я з масиву
your_name = D[D['name'] == 'Nazar']['name'][0]

print(f"Ваше ім'я з масиву: {your_name}")

homework("""Створив додаткове поле group - яке буде вказувавти групу. 
Дописав своє імя, оцінку та групу до масиву. 
Зберіг та вичитав дані у файл.
Прочитав саме своє імя з масиву.""")
# Out:
# Вихідний масив:  [('Bohdan', 4, 'A') ('Marta', 5, 'B') ('Noname', 0, 'C') ('Nazar', 4, 'B')]
# Прочитаний з файлу:  [('Bohdan', 4, 'A') ('Marta', 5, 'B') ('Noname', 0, 'C') ('Nazar', 4, 'B')]
# Записуємо у CSV файл temp.csv значення:
# [('Bohdan', 4, 'A') ('Marta', 5, 'B') ('Noname', 0, 'C') ('Nazar', 4, 'B')]
# Перевіряємо чи файл temp.csv створився: ['my_mass.npz', 'nb.ipynb', 'README.md', 'temp.csv']
# Читаємо файл за допомогою оператора with та методу readlines
# Прочитаний файл:
#  ['# name,mark,group\n', 'Bohdan,4,A\n', 'Marta,5,B\n', 'Noname,0,C\n', 'Nazar,4,B\n']
# - як бачимо - 5 елементи є стрічками <class 'str'>.
# Зчитане значення з файла:
#  [('Bohdan', 4, 'A') ('Marta', 5, 'B') ('Noname', 0, 'C') ('Nazar', 4, 'B')], як бачимо - 4 елементи це <class 'numpy.void'>
# - вбудований клас бібліотеки numpy.
# Доступитись до певного елемента можна наступним чином, наприклад імя першого елементу: Bohdan
# Ваше ім'я з масиву: Nazar
#
# ...
